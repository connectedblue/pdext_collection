# %%
import pandex as pd

pd.ext.import_extension('. -> wedge_plot')
pd.ext.reinstall_extension('wedge_plot')

# %%
df = pd.DataFrame({
    'League Cup': [8,5,2,5,6,4,4],
    'FA Cup': [7,12,13,8,6,8,2],
    'League Champions':[18,20,13,6,6,2,1],
    'UEFA Cup': [3,0,0,0,0,2,0],
    'European Cup':[6,3,0,1,0,0,2],
})
df.index=["Liverpool","Man United","Arsenal","Chelsea","Man City","Spurs", "Notts F"]
#df['teams']=["Liverpool","Man United","Arsenal","Chelsea","Man City","Spurs", "Notts F"]
#ring_values=['League Cup', 'FA Cup', 'League Champions','UEFA Cup','European Cup'], slice_labels='teams',
df
# Out:
#             League Cup  FA Cup  League Champions  UEFA Cup  European Cup
# Liverpool            8       7                18         3             6
# Man United           5      12                20         0             3
# Arsenal              2      13                13         0             0
# Chelsea              5       8                 6         0             1
# Man City             6       6                 6         0             0
# Spurs                4       8                 2         2             0
# Notts F              4       2                 1         0             2

# %%
fig=df.ext.wedge_plot()

# %%
fig = df.ext.wedge_plot(startangle=-40, all_slices_percent=0.30,alpha=.65, 
           hide_ring_label=False, slice_label_rotate=False, legend_fontstyle='italic', legend_fontweight='normal',
          legend_units=['cups','cups','titles','cups','cups',],
          title='English Football Clubs\nAll-Time Trophy Wins', explode=0.02, title_y=0.85, title_x=0.2,
          circle_label='2019', circle_fontsize=23, legend_y_start=-0.6, legend_gap=-0.1)

# %%
fig = df.ext.wedge_plot(startangle=-40, all_slices_percent=0.30,alpha=.65, legend_y_start=-.25, 
           hide_ring_label=False, slice_label_rotate=False, legend_fontstyle='italic', legend_fontweight='normal',
          legend_units=['cups','cups','titles','cups','cups',],
          title='English Football Clubs\nAll-Time Trophy Wins', explode=0.02, title_y=0.85, title_x=0.2,
          circle_label='2019', circle_fontsize=23, wedge_labels=None,
                       colours=['Purples', 'Greens','Purples', 'Greens','Purples'],
                       radius=[0.5, 0.7, 1.1, 1.5, 2],
                       wedge_width=[0.2, 0.2, 0.4, 0.4, 0.5],
                       ring_values=['League Cup', 'FA Cup', 'UEFA Cup'])

# %%
help(df.ext.wedge_plot)
